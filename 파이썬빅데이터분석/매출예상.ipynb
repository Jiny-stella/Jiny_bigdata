# %%
import pandas as pd

# %%
data1 = pd.read_csv('data.csv')
data1
print(data1.columns)
# Out:
# Index(['기준년월', '사업체id', 'pnu', '건물번호', '사업체명칭', '공정위업종중분류코드', '공정위업종중분류명칭',
#        '시도코드', '시도명칭', '시군구명칭',
#        ...
#        '70이상_여_야간상주인구', '야간상주인구_합계', '개발상권_대', '개발상권_중', '개발상권_소', 'x좌표',
#        'y좌표', 'x좌표(katec)', 'y좌표(katec)', '예상매출액'],
#       dtype='object', length=642)

# %%
# print(data1.columns)

data2 = data1[['기준년월','사업체id','건물번호','공정위업종중분류명칭','사업체명칭','공정위업종중분류코드','시군구명칭','행정동명칭','야간상주인구_합계','예상매출액']]
data2
# Out:
#           기준년월    사업체id                       건물번호    공정위업종중분류명칭  \
# 0       201806  5936355  3014010100100210000015443         패스트푸드
# 1       201806  1547751  3014010100100480002013544           이미용
# 2       201806  1547816  3014010100100520005027006            오락
# 3       201806  1547957  3014010100100650016013649           편의점
# 4       201806  1547966  3014010100100660009013799       의류 / 패션
# 5       201806  1547965  3014010100100660009013799       의류 / 패션
# 6       201806  5936585  3014010100101250007015899        기타 서비스
# 7       201806  1548180  3014010100101350000016710            중식
# 8       201806  1548322  3014010100101470002013398        부동산 중개
# 9       201806  1548938  3014010200100030012020222         인력 파견
# 10      201806  1549404  3014010200100890005002023            분식
# 11      201806  5090815  3014010200101040004000001        기타 서비스
# 12      201806  5937391  3014010200102290005015129            숙박
# ...

# %%
# 같은 사업체 명칭, 
data_x = data2[(data2['건물번호'] == '3014010100100210000015443')]
data_x
# Out:
#           기준년월    사업체id                       건물번호 공정위업종중분류명칭  \
# 0       201806  5936355  3014010100100210000015443      패스트푸드
# 8681    201806  1547601  3014010100100210000015443      인력 파견
# 20532   201807  1555016  3014010100100210000015443         커피
# 37752   201809  1510330  3014010100100210000015443      인력 파견
# 48431   201809  1510329  3014010100100210000015443      기타도소매
# 51576   201810  1519961  3014010100100210000015443         커피
# 63109   201810  5784069  3014010100100210000015443      패스트푸드
# 64568   201811  4776547  3014010100100210000015443      패스트푸드
# 74961   201811  1521712  3014010100100210000015443      기타도소매
# 91166   201812  1512832  3014010100100210000015443         커피
# 96068   201901  1508988  3014010100100210000015443      인력 파견
# 115483  201902  1513042  3014010100100210000015443      기타도소매
# 162831  201905  6986008  3014010100100210000015443      패스트푸드
#
#                    사업체명칭 공정위업종중분류코드 시군구명칭 행정동명칭    야간상주인구_합계   예상매출액
# ...

# %%
# 데이터 부족
data_y = data2[(data2['사업체id'] == 1548180)]
data_y
# Out:
#      기준년월    사업체id                       건물번호 공정위업종중분류명칭 사업체명칭 공정위업종중분류코드  \
# 7  201806  1548180  3014010100101350000016710         중식    초량        A11
#
#   시군구명칭 행정동명칭  야간상주인구_합계    예상매출액
# 7    중구   은행동       10.0  1303.98
